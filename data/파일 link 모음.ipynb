# %% [markdown]
# # Pickle
# IMG_SIZE = 224

# %%
# 결막염(무)
# !gdown 16yW3MR3-6Dq-CVcJcLuUNwoEpnfnKLIC
# 결막염(유)
# !gdown 1pKMO25KAV6XVWAIy1XilIj0wK8k2Ddr8

# 궤양성각막질환(무)
# !gdown 1FPEP98d3kOt0TDTRqbbYDQS6QdXh6fUy
# 궤양성각막질환(상)
# !gdown 1XfCM_NcJKI5twLoTgEAv4_1w3rCRkt7q
# 궤양성각막질환(하)
# !gdown 1DslFrz4P0JfhpP5L2pAKeg64n_k_qVAu

# 백내장
# !gdown 1g_xDhVHPm_tVshxrGA8MB9TWJ0tiElYi
# 백내장 비성숙
# !gdown 1kUZxPD5G4TGqn-kk27smWMYvt1OSq1HV
# 백내장 성숙
# !gdown 1HW1ow3qd0UZupEl4BtN-vWNkWpXbSg3u
# 백내장 초기
# !gdown 1g5WDflbH6aOUmGt4694KJn1dARGwSchU

# 비궤양성각막질환(무)
# !gdown 1IxCtHKnfSHRrIU5HW39vgmzLr0QYJWPO
# 비궤양성각막질환(상)
# !gdown 1gkFsq2VYJqiKlG-DMLqelEldfGc9VnLq
# 비궤양성각막질환(하)
# !gdown 1N4Y4wKPYBfjQGcyeWmEm8415_gZIFTDC

# 색소침착성각막염(무)
# !gdown 1oLJeBIIcqgfkFx_OV5f6UZaf83oapRAE
# 색소침착성각막염(유)
# !gdown 1SZo1-eriVfiRr9QXsup5tHbgOcaDbUM0

# 안검내반증(무)
# !gdown 1AMhSOW8Q2W3AYrJXSEoeuqJd6gWXjlng
# 안검내반증(유)
# !gdown 1P18Qo5gBXIvar1tM9yyG0EBUG5FtIYm_

# 안검염(무)
# !gdown 1ynKhluY7eufAOlUlOm_Kt0XthXC2NPRp
# 안검염(유)
# !gdown 1GDevV2c6nyF9w2-HMIyYCzFWGVV3mYzm

# 안검종양(무)
# !gdown 1DKpHpwKmGo2M8bldTt2TOYg6ZWQpOZMa
# 안검종양(유)
# !gdown 1qpD5r48uv-xYQVTs86L2xVQgoXGpD6jL

# 유루증(무)
# !gdown 10KDcT6NLn3Ok19wip4foMM8KridgRmWf
# 유루증(유)
# !gdown 1hrjPpH-xPLtS2qia1c66qKi4QCnPqXAG

# 핵경화(무)
# !gdown 1OT72s1HuRWhSqCpt5kNGJfQx5PE9hJvE
# 핵경화(유)
# !gdown 1Zs_HyyK3fwWltQK-8IK8xg36X9VuOM9l

# %% [markdown]
# # jpg
#
# IMG_SIZE = 224

# %%
# zip test
# %cd /content
# !gdown 1bsLEvlYF5Ey58deytoBm3nbgic5yEh97
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1bsLEvlYF5Ey58deytoBm3nbgic5yEh97
# To: /content/test.zip
# 100% 129k/129k [00:00<00:00, 84.2MB/s]

# %%
# zip test
# %cd /content
# !gdown 1hoSOTnRjjfpx72BU1duFyj4V1cJ0QVDD
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1hoSOTnRjjfpx72BU1duFyj4V1cJ0QVDD
# To: /content/새 폴더.zip
# 100% 492k/492k [00:00<00:00, 131MB/s]

# %%
# 파일명 설정
# !mkdir test_img
# %cd test_img
# Out:
# mkdir: cannot create directory ‘test_img’: File exists
# /content/test_img

# %%
# !unzip -qq "/content/새 폴더.zip"

# %%
# 결막염
# !gdown https://drive.google.com/uc?id=1qS5gF2WqYftAKE49JGA_8vSGaPAj3NRS
# # 궤양성각막질환
# !gdown https://drive.google.com/uc?id=1gYI4Icf0AX6vLVZmAeI7AJwQr04in-36
# # 백내장
# !gdown https://drive.google.com/uc?id=1uJxyfLXfF0lwJ7li1WNq2sD5JjYY1-fO
# # 비궤양성각막질환
# !gdown https://drive.google.com/uc?id=11Y5C26mecxzKg0fhesWEXEben89nyeoC
# # 색소침착성각막염
# !gdown https://drive.google.com/uc?id=1bbmclViF1wRxcsF-6KnGtNYTsXy-pMgA

# # 안검내반증
# !gdown https://drive.google.com/uc?id=14PqmZzih_iqtLogXN8ZBU5ug2DBhZWKF
# # 안검염
# !gdown https://drive.google.com/uc?id=1uOVsSPkEDiyQbaViduYyMXgt88GmsYAk
# # 안검종양
# !gdown https://drive.google.com/uc?id=1ZrRmn5y4m1q1JQh6Ig4GSR214kDCfuze
# # 유루증
# !gdown https://drive.google.com/uc?id=1BQ41PyE9emRo96uOjE2r7R30wUWNvckV
# # 핵경화
# !gdown https://drive.google.com/uc?id=1dZI37NVVgVv5kLJRhiF7WjfymiISEHEu
