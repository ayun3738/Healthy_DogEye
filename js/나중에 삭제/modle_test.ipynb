# %%
import os.path
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from pathlib import Path
from tqdm import tqdm
from time import perf_counter

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score
from IPython.display import Markdown, display

# %%
from tensorflow.keras import datasets, layers, models #Tensorflow에 있는 Keras 함수들 호출하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/image_recognition/data/save_sample/img
# Out:
# /content/drive/MyDrive/image_recognition/data/save_sample/img

# %%
# Out:
# Found 0 images belonging to 1 classes.

# %% [markdown]
# ### dataset
#
# - https://stickode.tistory.com/670

# %%
import tensorflow as tf
from tensorflow import keras
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                          validation_split=0.2)

# %%
import tensorflow as tf
from tensorflow import keras
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                          validation_split=0.1)


train_set = img_gen.flow_from_directory(directory="/content/drive/MyDrive/image_recognition/data/save_sample",
                                        target_size = (480,480),
                                        class_mode='categorical',
                                        subset='training', 
                                        batch_size = 32)
# Out:
# Found 9 images belonging to 1 classes.

# %%
test_set = img_gen.flow_from_directory(directory="/content/drive/MyDrive/image_recognition/data/save_sample",
                                        target_size = (480,480),
                                        class_mode='categorical',
                                        subset='validation',
                                        shuffle = False,
                                        batch_size = 32)
# Out:
# Found 1 images belonging to 1 classes.

# %%
image_data = img_gen.flow_from_directory(directory="/content/drive/MyDrive/image_recognition/data/save_sample",target_size = (480,480))
# Out:
# Found 10 images belonging to 1 classes.

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np

def get_class_string_from_index(index):
   for class_string, class_index in image_data.class_indices.items():
      if class_index == index:
         return class_string

x, y = next(train_set)
image = x[0, :, :, :]
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# import numpy as np
# import cv2
# from google.colab.patches import cv2_imshow
# def handle_image():
#   imgfile='/content/drive/MyDrive/image_recognition/data/save_sample/img/D0_0dbcc2c0-60a5-11ec-8402-0a7404972c70.jpg'
#   img=cv2.imread(imgfile, cv2. IMREAD_COLOR)
#   imgfile=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#   cv2_imshow(img)

# if __name__=='__main__':
#   handle_image()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from tensorflow.keras import datasets, layers, models #Tensorflow에 있는 Keras 함수들 호출하기

# %%
model = ResNet50(include_top=True, input_shape = (224, 224 ,3), weights = 'imagenet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-603a4b6b4934> in <module>
# ----> 1 (train_images, train_labels), (test_images, test_labels) = image_data.load_data()  # load_data() 가 4개 리턴되니 변수 4개로 설정
#
# AttributeError: 'DirectoryIterator' object has no attribute 'load_data'

# %%
(train_images, train_labels), (test_images, test_labels) = train_set.load_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-cb7edb2be179> in <module>
# ----> 1 (train_images, train_labels), (test_images, test_labels) = train_set.load_data()
#
# AttributeError: 'DirectoryIterator' object has no attribute 'load_data'

# %%
# (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()  # cifar10 10가지의 데이터셋, 연구목적

# train_images = train_images.reshape((50000, 32,32,3))
# test_images = test_images.reshape((10000, 32,32,3))

# # 픽셀 값을 0~1 사이로 정규화합니다.
# train_images, test_images = train_images / 255.0, test_images / 255.0

# plt.figure(figsize=(20,20))
# for i in range(100):
#     plt.subplot(10,10,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.imshow(train_images[i], cmap=plt.cm.binary)
# plt.show()

# %%
# model = models.Sequential()
# model.add(layers.Conv2D(64, (3, 3), activation='relu',input_shape=(32, 32, 3)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(128, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(256, (3, 3), activation='relu'))

# model.add(layers.Flatten())
# model.add(layers.Dense(128, activation='relu'))
# model.add(layers.Dense(10, activation='softmax'))

# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# model.fit(train_images, train_labels, epochs=10,verbose=1)

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# print(test_acc)
# Out:
# Epoch 1/10
#  224/1563 [===>..........................] - ETA: 2:56 - loss: 1.9677 - accuracy: 0.2497
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e05fc64392c9> in <module>
#      14               metrics=['accuracy'])
#      15
# ---> 16 model.fit(train_images, train_labels, epochs=10,verbose=1)
#      17
#      18 test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
