# %%
cd
# Out:
# /home/rara

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time 
import urllib.request 
import os
from selenium.webdriver.chrome.options import Options

url = "https://www.google.co.kr/imghp?hl=ko&ogbl" 
options = Options()
options.add_argument("--headless") # or use pyvirtualdiplay
options.add_argument("--no-sandbox") # needed, because colab runs as root

# 창을 켤건지 끌건지
options.headless = False

driver = webdriver.Chrome("/home/rara/Downloads/selenium_forder/chromedriver", options=options)

driver.get(url) # 구글이미지 검색 켜짐
print(driver.title)
search = "강아지 색소침착성 각막염"  # 검색어
elem = driver.find_element_by_name("q") # 구글 검색창 선책
elem.send_keys(search) # 검색창에 검색할 내용 넣기
elem.send_keys(Keys.RETURN) # 검색할 내용 넣고 Enter

SCROLL_PAUSE_TIME = 1
 
last_height = driver.execute_script("return document.body.scrollHeight")
 
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
 
    time.sleep(SCROLL_PAUSE_TIME)
 
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
count = 1
for image in images:
    try: 
        image.click()
        time.sleep(2)
        imgUrl = driver.find_element_by_xpath('//*[@id="Sva75c"]/div[2]/div/div[2]/div[2]/div[2]/c-wiz/div/div[1]/div[2]/div[2]/div/a/img').get_attribute('src')
        print(imgUrl)

        urllib.request.urlretrieve(imgUrl, '/home/rara/raheo/5/' + search + str(count))
        count = count + 1
    except:
        pass

driver.close()
# Out:
# Google 이미지
# https://post-phinf.pstatic.net/MjAxODA0MTdfOTcg/MDAxNTIzOTU2NzYxNjQy.4ThzSFtNfHJi6JFZEipsN_G5SIj0UUMhA_j-40vA4Hog.ds3tW9VSyXIOss_-TC3TQXzCEeqSVZcznwPFUqIHOkog.JPEG/%ED%83%84%EC%9D%B4.jpg?type=w1200
# https://m.zignature.co.kr/web/upload/NNEditor/20210324/dog-5223097_1920.jpg
# https://mblogthumb-phinf.pstatic.net/20160630_209/eoulimah_1467265566460KgP8F_JPEG/ffff.JPG?type=w800
# https://www.olchiolchi.com/wp-content/uploads/2015/12/%EC%82%AC%EC%A7%84217.jpg
# https://7500clinic.com/data/editor/p_1893/1503/7a351e71be104358efcb6953dcc7402d_1425606940_1.jpg
# https://i.ytimg.com/vi/MRZ95eGPl3w/maxresdefault.jpg
# https://7500clinic.com/data/editor/p_1893/1503/7a351e71be104358efcb6953dcc7402d_1425607008_58.jpg
# data:image/jpeg;base64,...
# https://blog.kakaocdn.net/dn/vaUUR/btqKsop4ODz/wlpU9XAP4w2jm4DRFh0sy0/img.jpg
# data:image/jpeg;base64,...
# https://m.harimpetfood.com/web/_data/editor_attach/board_gallery_4/gallery_4_365/355b1be74599a5eb580a0f8003d52370.jpg
# ...

# %%
cd /home/rara/Downloads/ra/
# Out:
# /home/rara/Downloads/ra
